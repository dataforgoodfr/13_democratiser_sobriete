# %%
import json
import os
import sys

import boto3
from dotenv import load_dotenv
import pandas as pd
from tqdm.notebook import tqdm

load_dotenv()
# Out:
# True

# %%
def get_chunk_url(i: int, stage2: bool = True):
    if stage2:
        return f"https://sufficiency-library.s3.fr-par.scw.cloud/stage-2/preds/chunk_{i}.parquet"
    else:
        return f"https://sufficiency-library.s3.fr-par.scw.cloud/stage-1/chunk_{i}.parquet"

# %%
# you needs lots of RAM for this
# I used the same compute instance used for the predictions, but you can optimize it much more by filtering as you load
res = []
for i in range(11, 25):
    url = get_chunk_url(i)
    df = pd.read_parquet(url)
    res.append(df)
    print(i, 'ok')
# Out:
# 11 ok
# 12 ok
# 13 ok
# 14 ok
# 15 ok
# 16 ok
# 17 ok
# 18 ok
# 19 ok
# 20 ok
# 21 ok
# 22 ok
# 23 ok
# 24 ok

# %%
allpreds = pd.concat(res, ignore_index=True)

# %%
allpreds
# Out:
#                    id                                              title  \
# 0         W1000006914  Cardiolipin Profile Changes are Associated to ...
# 1          W100011079  Economic impact of onchocerciasis through the ...
# 2         W1000067844  The Convention on International Trade in Endan...
# 3          W100016882  Investigations and actions taken during 2011 d...
# 4         W1000090685  Development of a Test Procedure for Driver Ass...
# ...               ...                                                ...
# 17324450  W4412403130  Curvature-dependent dynamics of a bacterium co...
# 17324451  W4412538833  Self-Attentive Transformer for Fast and Accura...
# 17324452  W4287812263  Asymptotically Achieving Centralized Rate on t...
# 17324453  W4411946848  An atlas of photonic and plasmonic materials f...
# 17324454  W4412476806  Super-Resolution for Renewable Energy Resource...
#
#                                                    abstract language  \
# 0         Brain mitochondria are fundamental to maintain...       en
# 1         This note overviews several studies that have ...       en
# 2         The 1973 Convention on International Trade in ...       en
# 3         Echinococcus multilocularis is a parasite that...       en
# 4         Accidents between right turning trucks and str...       en
# ...                                                     ...      ...
# 17324450  We investigate the positional behavior of a si...       en
# 17324451  Abstract Current postprocessing techniques oft...       en
# 17324452  We analyze the high-SNR regime of the MxK Netw...       en
# 17324453  Abstract Cathodoluminescence (CL) microscopy h...       en
# 17324454  With a potentially increasing share of the ele...       en
#
#           proba_other  proba_planetary_boundaries  proba_well_being  \
# 0            0.853108                    0.034522          0.039105
# 1            0.028584                    0.491196          0.373877
# 2            0.057553                    0.751890          0.029672
# 3            0.784568                    0.092691          0.034864
# 4            0.623844                    0.330110          0.031617
# ...               ...                         ...               ...
# 17324450     0.853631                    0.033652          0.037252
# 17324451     0.551830                    0.438791          0.027694
# 17324452     0.854295                    0.035799          0.038473
# 17324453     0.853834                    0.034404          0.036791
# 17324454     0.116185                    0.776198          0.034069
#
#           proba_resources  proba_justice  prescreening_high  \
# 0                0.038509       0.035241              False
# 1                0.042916       0.017946               True
# 2                0.050781       0.049556               True
# 3                0.027405       0.033613              False
# 4                0.019972       0.025730              False
# ...                   ...            ...                ...
# 17324450         0.039866       0.036489              False
# 17324451         0.021773       0.023525              False
# 17324452         0.039041       0.033799              False
# 17324453         0.039824       0.036168              False
# 17324454         0.029266       0.031723               True
#
#           prescreening_medium  prescreening_low            pred_class
# 0                       False             False                 other
# 1                       False             False  planetary_boundaries
# 2                        True             False  planetary_boundaries
# 3                       False             False                 other
# 4                       False             False                 other
# ...                       ...               ...                   ...
# 17324450                False             False                 other
# 17324451                False             False                 other
# 17324452                False             False                 other
# 17324453                False             False                 other
# 17324454                 True             False  planetary_boundaries
#
# [17324455 rows x 13 columns]

# %%
print(allpreds['prescreening_low'].mean())
print(allpreds['prescreening_low'].sum())
# Out:
# 0.14487705385248772
# 2509916

# %%
kept = allpreds[allpreds['prescreening_low']]

# %%
s3 = boto3.client(
        service_name="s3",
        endpoint_url="https://s3.fr-par.scw.cloud",
        aws_access_key_id=os.environ["S3_ACCESS_KEY"],
        aws_secret_access_key=os.environ["S3_SECRET_KEY"],
    )

# %%
kept.to_parquet('screened_preds.parquet', index=False)

# %%
s3.upload_file(
        Filename="screened_preds.parquet",
        Bucket="sufficiency-library",
        Key=f"stage-2/all_screened_with_preds.parquet",
    )

# %%
with open("screened_ids.txt", 'w', encoding='utf-8') as f:
    for i, row in tqdm(kept.iterrows(), total=len(kept)):
        value = row['id']
        f.write(str(value) + '\n')
# Out:
#   0%|          | 0/2509916 [00:00<?, ?it/s]

# %%
s3.upload_file(
        Filename="screened_ids.txt",
        Bucket="sufficiency-library",
        Key=f"stage-2/all_screened_ids.txt",
    )

# %% [markdown]
# # Now form final prescreening DB by taking all stage 1 data for kept ids

# %%
# again you can optimize this a lot more, I'm just enjoing my 189 GB of RAM
res = []
for i in range(25):
    url = get_chunk_url(i, stage2=False)
    df = pd.read_parquet(url)
    res.append(df)
    print(i, 'ok')
# Out:
# 0 ok
# 1 ok
# 2 ok
# 3 ok
# 4 ok
# 5 ok
# 6 ok
# 7 ok
# 8 ok
# 9 ok
# 10 ok
# 11 ok
# 12 ok
# 13 ok
# 14 ok
# 15 ok
# 16 ok
# 17 ok
# 18 ok
# 19 ok
# 20 ok
# 21 ok
# 22 ok
# 23 ok
# 24 ok

# %%
alldata = pd.concat(res, ignore_index=True)

# %%
df = alldata[alldata.id.isin(kept.id)]

# %%
df.isna().sum()
# Out:
# id                       0
# doi                 429268
# title                    0
# abstract                 0
# language                 0
# publication_date      1341
# type                     0
# open_access              0
# best_oa_location    768671
# has_fulltext             0
# fwci                170140
# created_at               0
# dtype: int64

# %%
sys.getsizeof(df) / 1024**2
# Out:
# 8619.808549880981

# %%
df.head()
# Out:
#              id                                              doi  \
# 20  W1000221716                                             None
# 21   W100006350                                             None
# 33  W1000233381  https://doi.org/10.12736/issn.2300-3022.2013212
# 44  W1000028557                 https://doi.org/10.3133/ofr93101
# 48  W1000134164              https://doi.org/10.3133/sir20055079
#
#                                                 title  \
# 20              Integrated management of leafy spurge
# 21  Farm Consolidation in the Northern and Central...
# 33  The lower Vistula in the aspect of the E40 and...
# 44  Occurrence of pesticides, nitrite plus nitrate...
# 48  Feasibility of using benthic invertebrates as ...
#
#                                              abstract language  \
# 20  Figure 1. Leafy spurge plant in flowering grow...       en
# 21  During the past half century, American agricul...       en
# 33  Throughout the history of Europe and the world...       en
# 44  During 1988, pesticides were detected in 4 of ...       en
# 48  Macroinvertebrates were collected from 19 site...       en
#
#    publication_date     type  \
# 20       1995-01-01  article
# 21       1987-01-01  article
# 33       2013-06-03  article
# 44       1993-01-01  article
# 48       2005-01-01  article
#
#                                           open_access  \
# 20  {"is_oa": true, "oa_status": "green", "oa_url"...
# 21  {"is_oa": true, "oa_status": "green", "oa_url"...
# 33  {"is_oa": false, "oa_status": "closed", "oa_ur...
# 44  {"is_oa": true, "oa_status": "bronze", "oa_url...
# 48  {"is_oa": false, "oa_status": "closed", "oa_ur...
#
#                                      best_oa_location  has_fulltext  \
# 20  {"id": "pmh:oai:library.ndsu.edu:10365/17688",...           1.0
# 21  {"id": "pmh:oai:digitalcommons.unl.edu:greatpl...           1.0
# 33                                               None           0.0
# 44  {"id": "doi:10.3133/ofr93101", "is_oa": true, ...           1.0
# 48                                               None           0.0
#
#           fwci           created_at
# 20  1.44102389  2025-12-01 18:23:11
# 21         0.0  2025-12-01 18:23:11
# 33  0.48269519  2025-12-01 18:23:11
# 44         0.0  2025-12-01 18:23:11
# 48         0.0  2025-12-01 18:23:11

# %%
oa = pd.json_normalize(df.open_access.apply(json.loads))

# %%
oa
# Out:
#          is_oa oa_status                                             oa_url  \
# 0         True     green                  http://hdl.handle.net/10365/17688
# 1         True     green  http://digitalcommons.unl.edu/cgi/viewcontent....
# 2        False    closed                                               None
# 3         True    bronze      https://pubs.usgs.gov/of/1993/0101/report.pdf
# 4        False    closed                                               None
# ...        ...       ...                                                ...
# 2509911  False    closed                                               None
# 2509912  False    closed                                               None
# 2509913  False    closed                                               None
# 2509914   True     green   https://doi.org/10.20944/preprints202412.1402.v1
# 2509915   True      gold       https://doi.org/10.5194/egusphere-egu22-8553
#
#          any_repository_has_fulltext
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
# ...                              ...
# 2509911                        False
# 2509912                        False
# 2509913                        False
# 2509914                        False
# 2509915                        False
#
# [2509916 rows x 4 columns]

# %%
oa.is_oa.sum()
# Out:
# np.int64(1741245)

# %%
df.has_fulltext.sum()
# Out:
# np.float64(1177999.0)

# %%
oa.any_repository_has_fulltext.sum()
# Out:
# np.int64(0)

# %%
boa = pd.json_normalize(df.best_oa_location.apply(lambda x: json.loads(x) if x else None))

# %%
boa.head()
# Out:
#                                                   id is_oa  \
# 0               pmh:oai:library.ndsu.edu:10365/17688  True
# 1  pmh:oai:digitalcommons.unl.edu:greatplainsquar...  True
# 2                                                NaN   NaN
# 3                               doi:10.3133/ofr93101  True
# 4                                                NaN   NaN
#
#                                     landing_page_url  \
# 0                  http://hdl.handle.net/10365/17688
# 1  http://digitalcommons.unl.edu/greatplainsquart...
# 2                                                NaN
# 3                   https://doi.org/10.3133/ofr93101
# 4                                                NaN
#
#                                              pdf_url license license_id  \
# 0                  http://hdl.handle.net/10365/17688    None       None
# 1  http://digitalcommons.unl.edu/cgi/viewcontent....    None       None
# 2                                                NaN     NaN        NaN
# 3      https://pubs.usgs.gov/of/1993/0101/report.pdf    None       None
# 4                                                NaN     NaN        NaN
#
#             version is_accepted is_published         raw_source_name  ...  \
# 0  submittedVersion       False        False      NDSU Extension 866  ...
# 1  submittedVersion       False        False  Great Plains Quarterly  ...
# 2               NaN         NaN          NaN                     NaN  ...
# 3  publishedVersion        True         True        Open-File Report  ...
# 4               NaN         NaN          NaN                     NaN  ...
#
#                          source.issn source.is_oa source.is_in_doaj  \
# 0                               None        False             False
# 1                               None        False             False
# 2                                NaN          NaN               NaN
# 3  [0196-1497, 2331-1258, 2332-4899]        False             False
# 4                                NaN          NaN               NaN
#
#   source.is_core          source.host_organization  \
# 0          False    https://openalex.org/I57328836
# 1          False   https://openalex.org/I114395901
# 2            NaN                               NaN
# 3           True  https://openalex.org/P4310316088
# 4            NaN                               NaN
#
#               source.host_organization_name  \
# 0             North Dakota State University
# 1            University of Nebraska–Lincoln
# 2                                       NaN
# 3  United States Department of the Interior
# 4                                       NaN
#
#      source.host_organization_lineage source.host_organization_lineage_names  \
# 0    [https://openalex.org/I57328836]                                     []
# 1   [https://openalex.org/I114395901]                                     []
# 2                                 NaN                                    NaN
# 3  [https://openalex.org/P4310316088]                                     []
# 4                                 NaN                                    NaN
#
#   source.type source
# 0  repository    NaN
# 1  repository    NaN
# 2         NaN    NaN
# 3     journal    NaN
# 4         NaN    NaN
#
# [5 rows x 24 columns]

# %%
df.best_oa_location.notna().sum()
# Out:
# np.int64(1741245)

# %%
boa.is_oa.sum()
# Out:
# 1741245

# %%
boa.is_oa.dropna().value_counts()
# Out:
# is_oa
# True    1741245
# Name: count, dtype: int64

# %%
boa.columns
# Out:
# Index(['id', 'is_oa', 'landing_page_url', 'pdf_url', 'license', 'license_id',
#        'version', 'is_accepted', 'is_published', 'raw_source_name', 'raw_type',
#        'source.id', 'source.display_name', 'source.issn_l', 'source.issn',
#        'source.is_oa', 'source.is_in_doaj', 'source.is_core',
#        'source.host_organization', 'source.host_organization_name',
#        'source.host_organization_lineage',
#        'source.host_organization_lineage_names', 'source.type', 'source'],
#       dtype='object')

# %%
(oa.is_oa == boa.is_oa.fillna(False)).mean()
# Out:
# /tmp/ipykernel_5192/1136568084.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   (oa.is_oa == boa.is_oa.fillna(False)).mean()
# np.float64(1.0)

# %%
(oa.oa_url == boa.pdf_url).mean()
# Out:
# np.float64(0.5557492760713905)

# %%
(oa.oa_url == boa.landing_page_url).mean()
# Out:
# np.float64(0.19706316864787507)

# %%
oa.oa_url.notna().sum()
# Out:
# np.int64(1738030)

# %%
boa.pdf_url.notna().sum()
# Out:
# np.int64(1394884)

# %%
boa.landing_page_url.notna().sum()
# Out:
# np.int64(1714634)

# %%
m = (oa.oa_url == boa.pdf_url) | (oa.oa_url == boa.landing_page_url)
oa[~m].oa_url.notna().sum()  # 0 means oa.oa_url is always boa.pdf_url or boa.landing_page when not null
# Out:
# np.int64(0)

# %%
m.sum()
# Out:
# np.int64(1738030)

# %% [markdown]
# best_oa_location is here exactly when oa.is_oa is True, and then oa.oa_url is always either boa.pdf_url or boa.landing_page_url

# %%
oadf = pd.concat([oa[['is_oa', 'oa_status']], boa[['landing_page_url', 'pdf_url']]], axis=1)

# %%
oadf
# Out:
#          is_oa oa_status                                   landing_page_url  \
# 0         True     green                  http://hdl.handle.net/10365/17688
# 1         True     green  http://digitalcommons.unl.edu/greatplainsquart...
# 2        False    closed                                                NaN
# 3         True    bronze                   https://doi.org/10.3133/ofr93101
# 4        False    closed                                                NaN
# ...        ...       ...                                                ...
# 2509911  False    closed                                                NaN
# 2509912  False    closed                                                NaN
# 2509913  False    closed                                                NaN
# 2509914   True     green   https://doi.org/10.20944/preprints202412.1402.v1
# 2509915   True      gold       https://doi.org/10.5194/egusphere-egu22-8553
#
#                                                    pdf_url
# 0                        http://hdl.handle.net/10365/17688
# 1        http://digitalcommons.unl.edu/cgi/viewcontent....
# 2                                                      NaN
# 3            https://pubs.usgs.gov/of/1993/0101/report.pdf
# 4                                                      NaN
# ...                                                    ...
# 2509911                                                NaN
# 2509912                                                NaN
# 2509913                                                NaN
# 2509914                                               None
# 2509915                                               None
#
# [2509916 rows x 4 columns]

# %%
oadf.iloc[-2]['landing_page_url']
# Out:
# 'https://doi.org/10.20944/preprints202412.1402.v1'

# %%
oadf
# Out:
#          is_oa oa_status                                   landing_page_url  \
# 0         True     green                  http://hdl.handle.net/10365/17688
# 1         True     green  http://digitalcommons.unl.edu/greatplainsquart...
# 2        False    closed                                                NaN
# 3         True    bronze                   https://doi.org/10.3133/ofr93101
# 4        False    closed                                                NaN
# ...        ...       ...                                                ...
# 2509911  False    closed                                                NaN
# 2509912  False    closed                                                NaN
# 2509913  False    closed                                                NaN
# 2509914   True     green   https://doi.org/10.20944/preprints202412.1402.v1
# 2509915   True      gold       https://doi.org/10.5194/egusphere-egu22-8553
#
#                                                    pdf_url
# 0                        http://hdl.handle.net/10365/17688
# 1        http://digitalcommons.unl.edu/cgi/viewcontent....
# 2                                                      NaN
# 3            https://pubs.usgs.gov/of/1993/0101/report.pdf
# 4                                                      NaN
# ...                                                    ...
# 2509911                                                NaN
# 2509912                                                NaN
# 2509913                                                NaN
# 2509914                                               None
# 2509915                                               None
#
# [2509916 rows x 4 columns]

# %%
a = df.drop(columns=['open_access', 'best_oa_location', 'created_at'])
final = pd.concat((a.reset_index(drop=True), oadf), axis=1)

# %%
final
# Out:
#                   id                                               doi  \
# 0        W1000221716                                              None
# 1         W100006350                                              None
# 2        W1000233381   https://doi.org/10.12736/issn.2300-3022.2013212
# 3        W1000028557                  https://doi.org/10.3133/ofr93101
# 4        W1000134164               https://doi.org/10.3133/sir20055079
# ...              ...                                               ...
# 2509911  W2112656034          https://doi.org/10.7325/galemys.2012.a05
# 2509912  W2159214726                                              None
# 2509913   W266132455                                              None
# 2509914  W4405528638  https://doi.org/10.20944/preprints202412.1402.v1
# 2509915  W4220663542      https://doi.org/10.5194/egusphere-egu22-8553
#
#                                                      title  \
# 0                    Integrated management of leafy spurge
# 1        Farm Consolidation in the Northern and Central...
# 2        The lower Vistula in the aspect of the E40 and...
# 3        Occurrence of pesticides, nitrite plus nitrate...
# 4        Feasibility of using benthic invertebrates as ...
# ...                                                    ...
# 2509911  Habitat suitability model for red deer (Cervus...
# 2509912  Heavy metal concentrations in the topsoils of ...
# 2509913  Determination of the upper threshold value for...
# 2509914  UV Map Nowcasting and Comparison with Ground-B...
# 2509915  Nitrate contamination in the chalk aquifer of ...
#
#                                                   abstract language  \
# 0        Figure 1. Leafy spurge plant in flowering grow...       en
# 1        During the past half century, American agricul...       en
# 2        Throughout the history of Europe and the world...       en
# 3        During 1988, pesticides were detected in 4 of ...       en
# 4        Macroinvertebrates were collected from 19 site...       en
# ...                                                    ...      ...
# 2509911  Monitoring population trends is essential in w...       en
# 2509912  In the Dutch part of the area, heavy metal con...       en
# 2509913  Using reclaimed water for greenbelt irrigation...       en
# 2509914  This study introduces a new method for nowcast...       en
# 2509915  &amp;lt;p&amp;gt;The problem of nitrate contam...       en
#
#         publication_date      type  has_fulltext        fwci  is_oa oa_status  \
# 0             1995-01-01   article           1.0  1.44102389   True     green
# 1             1987-01-01   article           1.0         0.0   True     green
# 2             2013-06-03   article           0.0  0.48269519  False    closed
# 3             1993-01-01   article           1.0         0.0   True    bronze
# 4             2005-01-01   article           0.0         0.0  False    closed
# ...                  ...       ...           ...         ...    ...       ...
# 2509911       2012-12-31   article           0.0   0.2588458  False    closed
# 2509912       2007-01-01   article           0.0         0.0  False    closed
# 2509913       2009-01-01   article           0.0         0.0  False    closed
# 2509914       2024-12-18  preprint           0.0         0.0   True     green
# 2509915       2022-03-27  preprint           0.0         0.0   True      gold
#
#                                           landing_page_url  \
# 0                        http://hdl.handle.net/10365/17688
# 1        http://digitalcommons.unl.edu/greatplainsquart...
# 2                                                      NaN
# 3                         https://doi.org/10.3133/ofr93101
# 4                                                      NaN
# ...                                                    ...
# 2509911                                                NaN
# 2509912                                                NaN
# 2509913                                                NaN
# 2509914   https://doi.org/10.20944/preprints202412.1402.v1
# 2509915       https://doi.org/10.5194/egusphere-egu22-8553
#
#                                                    pdf_url
# 0                        http://hdl.handle.net/10365/17688
# 1        http://digitalcommons.unl.edu/cgi/viewcontent....
# 2                                                      NaN
# 3            https://pubs.usgs.gov/of/1993/0101/report.pdf
# 4                                                      NaN
# ...                                                    ...
# 2509911                                                NaN
# 2509912                                                NaN
# 2509913                                                NaN
# 2509914                                               None
# 2509915                                               None
#
# [2509916 rows x 13 columns]

# %%
final.to_parquet('screened_alldata.parquet', index=False)

# %%
s3.upload_file(
        Filename="screened_alldata.parquet",
        Bucket="sufficiency-library",
        Key="library_v1_2025-12-08.parquet",
    )

# %%
import pandas as pd
import os
from pathlib import Path

try:
    import rispy
except ImportError:
    # !pip install rispy --quiet

# %%
df = pd.read_csv(
    "../data/all_documents_general_query.csv",
    usecols=["doi", "title", "abstract", "concepts", "keywords"],
    dtype={"doi": str, "title": str, "abstract": str, "concepts": str, "keywords": str},
).drop_duplicates().reset_index(drop=True)

# %%
def parse_keywords(keywords):
    if pd.isna(keywords):
        return []
    keywords = keywords.split("|")
    keywords = [keyword.split(":")[0] for keyword in keywords]
    return keywords


# Parse the keywords column and change the dtype to categorical
df["keywords_cats"] = df["keywords"].apply(parse_keywords)

# %%
df.head()
# Out:
#                                                  doi  \
# 0  https://doi.org/10.1002/1096-8644(200007)112:3...
# 1              https://doi.org/10.1093/molbev/msv045
# 2                 https://doi.org/10.3390/su13031436
# 3         https://doi.org/10.1016/j.wace.2015.07.003
# 4         https://doi.org/10.5210/spir.v2024i0.13937
#
#                                                title  \
# 0  Age-dependent cortical bone loss in women from...
# 1  Model-Based Verification of Hypotheses on the ...
# 2  Horticulture and Orchards as New Markets for M...
# 3  Why well yield matters for managing agricultur...
# 4  INDUSTRY INFLUENCE ON CONTENT MODERATION REGUL...
#
#                                             abstract  \
# 0  Age-dependent cortical bone loss was investiga...
# 1  Various hypotheses for the peopling of the Jap...
# 2  Animal manure management is a real challenge t...
# 3  Groundwater-fed irrigation has supported growt...
# 4  As the EU Digital Services Act increasingly in...
#
#                                             concepts  \
# 0  Late 19th century:0.7359046|Cortical bone:0.56...
# 1  Biology:0.8816396|Inference:0.6029327|Genome:0...
# 2  Manure:0.8611909|Agriculture:0.64704436|Contex...
# 3  Agriculture:0.695057|Climate change:0.6315455|...
# 4  Moderation:0.8861263|Civil society:0.6190976|P...
#
#                                             keywords  \
# 0                        Late 19th century:0.7359046
# 1                                     SNP:0.53888464
# 2  Valorisation:0.5449556|Manure management:0.482...
# 3                                                NaN
# 4  Moderation:0.8861263|Civil Society:0.6190976|C...
#
#                                        keywords_cats
# 0                                [Late 19th century]
# 1                                              [SNP]
# 2  [Valorisation, Manure management, Chicken manure]
# 3                                                 []
# 4  [Moderation, Civil Society, Content (measure t...

# %%
def get_all_keywords(path):
    """
    Get all keywords from a RIS file.
    :param path: Path to the RIS file.
    :return: Keywords as pandas Series.
    """
    keyword_list = []
    with open(path, "r") as f:
        ris_data = rispy.load(f)
        for entry in ris_data:
            try:
                keyword_list.append(entry["keywords"])
            except KeyError as e:
                print(
                    f"KeyError: entry does not contain 'keywords'. Keys: {entry.keys()}"
                )
                raise e
    return pd.DataFrame({"keywords": keyword_list})


sectors = os.listdir("ETL_all_sectors/raw_data")
full_dataset = []
for sector in sectors:
    print(f"Processing sector: {sector}")
    df_list = []

    # Get all files in the sector directory
    sector_files = os.listdir(os.path.join("ETL_all_sectors/raw_data", sector))
    sector_files = [
        Path(os.path.join("ETL_all_sectors/raw_data", sector, f)) for f in sector_files
    ]
    sector_files_types = [f.suffix for f in sector_files]

    if ".csv" in sector_files_types:
        # Freight CSV Case
        for file in sector_files:
            print(f"Processing file: {file}")
            # If a CSV file is present, read it
            tmp_df = pd.read_csv(
                file, sep=";", usecols=["keywords"], encoding_errors="replace"
            )
            df_list.append(tmp_df)

    elif ".ris" in sector_files_types or ".txt" in sector_files_types:
        # RIS or TXT Case
        for file in sector_files:
            print(f"Processing file: {file}")
            tmp_df = get_all_keywords(file)
            df_list.append(tmp_df)
    else:
        raise ValueError(
            f"No valid file types found in {sector}. Expected .csv, .ris, or .txt files."
        )

combined_df = pd.concat(df_list, ignore_index=True)
# Out:
# Processing sector: Nutrition
# Processing file: ETL_all_sectors/raw_data/Nutrition/Nutrition Included.txt
# Processing file: ETL_all_sectors/raw_data/Nutrition/Nutrition Excluded.txt
# Processing sector: Urban_Infra
# Processing file: ETL_all_sectors/raw_data/Urban_Infra/UrbanInfra Excluded.ris
# Processing file: ETL_all_sectors/raw_data/Urban_Infra/UrbanInfra Included.ris
# Processing sector: Digitalisation
# Processing file: ETL_all_sectors/raw_data/Digitalisation/Digitalisation Included.txt
# Processing file: ETL_all_sectors/raw_data/Digitalisation/Digitalisation Excluded.txt
# Processing sector: Urban_Governance
# Processing file: ETL_all_sectors/raw_data/Urban_Governance/UrbanGovSuff Included.txt
# Processing file: ETL_all_sectors/raw_data/Urban_Governance/UrbanGovSuff Excluded.txt
# Processing sector: Freight
# Processing file: ETL_all_sectors/raw_data/Freight/Freight_Included.csv
# Processing file: ETL_all_sectors/raw_data/Freight/Freight Excluded.csv
# Processing sector: Urban_Ecology
# Processing file: ETL_all_sectors/raw_data/Urban_Ecology/Urban_Ecology_Excluded.txt
# Processing file: ETL_all_sectors/raw_data/Urban_Ecology/Urban_Ecology_Included.txt
# Processing sector: Buildings
# Processing file: ETL_all_sectors/raw_data/Buildings/Buildings Included.txt
# Processing file: ETL_all_sectors/raw_data/Buildings/Buildings Excluded.txt

# %%
# check and count all the unique keywords using a pandas Series and value counts
unique_keywords = df["keywords_cats"].explode().tolist()
unique_keywords_set = set(unique_keywords)
keyword_prior_knowledge = combined_df["keywords"].explode().tolist()
keyword_prior_knowledge_set = set(keyword_prior_knowledge)
print(f"Number of unique keywords in the dataset: {len(unique_keywords_set)}")
print(
    f"Number of unique keywords in the prior knowledge: {len(keyword_prior_knowledge_set)}"
)

# Count the number of common keywords between the two sets
common_keywords = unique_keywords_set.intersection(keyword_prior_knowledge_set)
print(f"Number of common keywords: {len(common_keywords)}")

# Count the number of different keywords between the two sets
different_keywords = keyword_prior_knowledge_set.symmetric_difference(
    unique_keywords_set
)
print(f"Number of different keywords: {len(different_keywords)}")
# Out:
# Number of unique keywords in the dataset: 413803
# Number of unique keywords in the prior knowledge: 16286
# Number of common keywords: 373
# Number of different keywords: 429343

# %%
common_keywords
# Out:
# {'Acculturation',
#  'Active transport',
#  'Adaptability',
#  'Adaptive capacity',
#  'Aerobic exercise',
#  'Affect',
#  'Affordable housing',
#  'Agricultural policy',
#  'Air filtration',
#  'Air movement',
#  'Altruism',
#  'Analytic network process',
#  'Annuity',
#  'Answer Set Programming',
#  'Appropriation',
#  'Asbestos cement',
#  'Asbestosis',
#  'Asset turnover',
#  'Attitude',
#  'Austerity',
#  'Backcasting',
#  'Bank credit',
#  'Bayesian Optimization',
#  'Behaviour change',
#  'Benchmarking',
#  'Binary logit model',
#  'Biomass fuels',
#  'Black Sea',
#  'Blue carbon',
#  'Bounded rationality',
#  'British Empire',
#  'Building Information Modeling',
#  'Building energy simulation',
#  'Building envelope',
#  'Building management',
#  'Building science',
#  'Bustard',
#  'Cadastre',
#  'Capacity Building',
#  'Car ownership',
#  'Car parking',
#  'Carbon neutrality',
#  'Caregiving',
#  'Carrion',
#  'Cash crop',
#  'Chi-square test',
#  'Chinese city',
#  'Choice modelling',
#  'Circular Economy',
#  'Circular economy',
#  'City centre',
#  'CityGML',
#  'Clean coal',
#  'Cleaner production',
#  'Climate governance',
#  'Coefficient of performance',
#  'Coevolution',
#  'Cognitive flexibility',
#  'Cold climate',
#  'College education',
#  'Commodification',
#  'Communicative competence',
#  'Community',
#  'Community Resilience',
#  'Compact city',
#  'Compassion',
#  'Conceptual design',
#  'Conceptual framework',
#  'Conceptual model',
#  'Connectivity',
#  'Conservation',
#  'Constrained optimization',
#  'Consumer behaviour',
#  'Consumer information',
#  'Consumption',
#  'Contingent valuation',
#  'Cooling capacity',
#  'Cooling load',
#  'Cosmopolitanism',
#  'County government',
#  'Cross laminated timber',
#  'Cross-Cultural',
#  'Crowdsourcing',
#  'CubeSat',
#  'Cumulative effects',
#  'Cycling',
#  'DMAIC',
#  'DPSIR',
#  'Daylight',
#  'Daylighting',
#  'Decision-making',
#  'Default',
#  'Deforestation',
#  'Density estimation',
#  'Depression',
#  'Design management',
#  'Deviance',
#  'Differentiation',
#  'Disruptive innovation',
#  'Dwarfism',
#  'Dynamic simulation',
#  'EQ-5D',
#  'East African Rift',
#  'Ecodesign',
#  'Ecological civilization',
#  'Ecological network',
#  'Economic recovery',
#  'Electricity demand',
#  'Employability',
#  'Endowment effect',
#  'Energy Efficiency',
#  'Energy economics',
#  'Energy mix',
#  'Energy requirement',
#  'Energy transition',
#  'Environmental design',
#  'Environmental stewardship',
#  'Equity',
#  'Evidence-based design',
#  'Exergy efficiency',
#  'Experimental economics',
#  'Exploratory factor analysis',
#  'Exploratory research',
#  'Facade',
#  'Facilitation',
#  'Facility management',
#  'Fall prevention',
#  'Fear of falling',
#  'Financialization',
#  'Flash flood',
#  'Food Waste',
#  'Forced convection',
#  'Foreclosure',
#  'Fragmentation',
#  'Gender justice',
#  'Generative Design',
#  'Gentrification',
#  'Global South',
#  'Graduate students',
#  'Graffiti',
#  'Green Building',
#  'Green infrastructure',
#  'Green roof',
#  'Ground beetle',
#  'Hazard map',
#  'Heliostat',
#  'Hierarchical clustering',
#  'Historiography',
#  'Hospitality',
#  'House price',
#  'Household debt',
#  'Household income',
#  'Housing tenure',
#  'Hydrocarbon exploration',
#  'Impact assessment',
#  'Impermanence',
#  'Impression management',
#  'Indexation',
#  'Indoor air',
#  'Information model',
#  'Installation art',
#  'Integrated design',
#  'Interaction',
#  'Interconnectivity',
#  'Interdisciplinarity',
#  'Intermediation',
#  'Internalization',
#  'Intersectionality',
#  'Kenya',
#  'Knowledge graph',
#  'LED lamp',
#  'Laterite',
#  'Learning curve',
#  'Legislative intent',
#  'Life Cycle Costing',
#  'Living lab',
#  'Localism',
#  'Locus of control',
#  'Long-term care insurance',
#  'Longitudinal data',
#  'Machiavellianism',
#  'Magnetostratigraphy',
#  'Maladaptation',
#  'Marine Spatial Planning',
#  'Marine ecosystem',
#  'Master plan',
#  'Material efficiency',
#  'Material flow analysis',
#  'Materiality',
#  'Maya',
#  'Mediator',
#  'Megacity',
#  'Mentorship',
#  'Metaverse',
#  'Metro station',
#  'Mexico city',
#  'Milankovitch cycles',
#  'Mode choice',
#  'Modelica',
#  'Monoculture',
#  'Morphology',
#  'Mortgage loan',
#  'Multi-level governance',
#  'Multidimensional analysis',
#  'Multimodality',
#  'Multiple correspondence analysis',
#  'Mutualism',
#  'Narrative therapy',
#  'Natura 2000',
#  'Natural Ventilation',
#  'Neotectonics',
#  'New england',
#  'New public management',
#  'Northern Ireland',
#  'Obsolescence',
#  'Occupancy',
#  'Organic Rankine Cycle',
#  'Organisational change',
#  'Outreach',
#  'Overgrazing',
#  'Panama',
#  'Pandemic',
#  'Parametric design',
#  'Participatory planning',
#  'Passive cooling',
#  'Passive house',
#  'Pastoralism',
#  'Pellet',
#  'Pentagon',
#  'Performance indicator',
#  'Photobioreactor',
#  'Physical exercise',
#  'Physical health',
#  'Phytolith',
#  'Place identity',
#  'Plant',
#  'Policy mix',
#  'Post-occupancy evaluation',
#  'Pozzolana',
#  'Precinct',
#  'Predictability',
#  'Preschool education',
#  'Price premium',
#  'Property tax',
#  'Psychological adaptation',
#  'Public land',
#  'Public space',
#  'Qualitative analysis',
#  'Quantile regression',
#  'Quantitative assessment',
#  'Radiant cooling',
#  'Rail transit',
#  'Rangeland management',
#  'Regionalism',
#  'Relocation',
#  'Resilience',
#  'Retrofitting',
#  'Right to education',
#  'River management',
#  'Rural housing',
#  'Rural population',
#  'Safeguarding',
#  'Salt marsh',
#  'Salutogenesis',
#  'Scenario analysis',
#  'Seismic risk',
#  'Self-knowledge',
#  'Self-organizing map',
#  'Semi-arid climate',
#  'Sense of Community',
#  'Sharecropping',
#  'Shared governance',
#  'Shetland',
#  'Simulation-based optimization',
#  'Simultaneous equations model',
#  'Single family',
#  'Skin conductance',
#  'Sleep',
#  'Smart contract',
#  'Smart environment',
#  'Social Entrepreneurship',
#  'Social Exclusion',
#  'Social Innovation',
#  'Social care',
#  'Social conflict',
#  'Social defeat',
#  'Social enterprise',
#  'Social life',
#  'Social trust',
#  'Soil series',
#  'Solar chimney',
#  'Solidarity Economy',
#  'Soundscape',
#  'Space Syntax',
#  'Spatial Planning',
#  'Spatial heterogeneity',
#  'Spatiotemporal pattern',
#  'Status quo bias',
#  'Stearic acid',
#  'Sterilization',
#  'Stewardship',
#  'Stigma',
#  'Stochastic frontier analysis',
#  'Strategic Environmental Assessment',
#  'Stress',
#  'Stroke',
#  'Structural approach',
#  'Suburbanization',
#  'Success factors',
#  'Suitability analysis',
#  'Supply',
#  'Sustainable Design',
#  'Sustainable Energy',
#  'Sustainable city',
#  'Sustainable community',
#  'Sustainable land management',
#  'Sustainable society',
#  'Sustainable transport',
#  'Synthetic data',
#  'Systematic risk',
#  'TOPSIS',
#  'TRNSYS',
#  'Territoriality',
#  'Theil index',
#  'Theory',
#  'Thermal mass',
#  'Thermosiphon',
#  'Tidal flat',
#  'Time geography',
#  'Time management',
#  'Toll road',
#  'Total Quality Management',
#  'Town planning',
#  'Trade-off',
#  'Transdisciplinarity',
#  'Transit-oriented development',
#  'Transport Network',
#  'Transportation planning',
#  'Trend analysis',
#  'Tropical climate',
#  'Twin cities',
#  'Uncertainty',
#  'Uncertainty Quantification',
#  'Urban Heat Island',
#  'Urban Morphology',
#  'Urban Space',
#  'Urban agglomeration',
#  'Urban ecology',
#  'Urban expansion',
#  'Urban forest',
#  'Urban greening',
#  'Urban infrastructure',
#  'Urban landscape',
#  'Urban sprawl',
#  'Urban studies',
#  'Urban village',
#  'Urbanity',
#  'Values',
#  'Verbal autopsy',
#  'Vernacular Architecture',
#  'Visible spectrum',
#  'Volunteer',
#  'Vulnerability',
#  'Walkability',
#  'Water Framework Directive',
#  'Wildness',
#  'Willingness to accept',
#  'Work environment',
#  'Zip code',
#  'energy demand',
#  'land-use change',
#  'nature',
#  'plague'}

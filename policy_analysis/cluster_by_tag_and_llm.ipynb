# %%
import pandas as pd
from openai import OpenAI
from tqdm.notebook import tqdm

# %% [markdown]
# ### Load policies

# %%
df = pd.read_parquet('../data/sample_10k_with_policies_extracted_tagged_v4_2026-01-30.parquet')
df
# Out:
#                                                     discussion  \
# openalex_id
# W4387168299  This is the first study to assess the associat...
# W3014778543  The main conclusions extracted from this study...
# W3048162401  LPG, CNG, ethanol and biodiesel are good candi...
# W1005805659  The results of the study revealed that growth ...
# W4319601041  In our use of participatory video, following R...
# ...                                                        ...
# W4390273040  Erosion is a significant issue impacting upon ...
# W4298143484  In this article, the individual and collective...
# W4387449772  Research findings\nAccording to the context of...
# W2623732815  A FDS Input Files\nList of Figures\nPredicted ...
# W3005356321  In this paper, we explored the causal relation...
#
#                                                       policies
# openalex_id
# W4387168299                                                 []
# W3014778543                                                 []
# W3048162401  [[MOBILITY] [REGULATORY] [NATIONAL] Policy sup...
# W1005805659  [[FOOD] [ECONOMIC] [NATIONAL] Investment in ag...
# W4319601041  [[NATURE] [PARTICIPATORY] [NGO] Use of partici...
# ...                                                        ...
# W4390273040                                                 []
# W4298143484                                                 []
# W4387449772  [[ENERGY] [REGULATORY] [NATIONAL] China has pr...
# W2623732815                                                 []
# W3005356321  [[INDUSTRY] [ORGANISATIONAL] [COMPANIES] Manag...
#
# [10000 rows x 2 columns]

# %%
pdf = df.explode("policies").reset_index()
pdf = pdf.dropna()
pdf
# Out:
#        openalex_id                                         discussion  \
# 2      W3048162401  LPG, CNG, ethanol and biodiesel are good candi...
# 3      W1005805659  The results of the study revealed that growth ...
# 4      W1005805659  The results of the study revealed that growth ...
# 5      W1005805659  The results of the study revealed that growth ...
# 6      W4319601041  In our use of participatory video, following R...
# ...            ...                                                ...
# 20905  W4387449772  Research findings\nAccording to the context of...
# 20906  W4387449772  Research findings\nAccording to the context of...
# 20908  W3005356321  In this paper, we explored the causal relation...
# 20909  W3005356321  In this paper, we explored the causal relation...
# 20910  W3005356321  In this paper, we explored the causal relation...
#
#                                                 policies
# 2      [MOBILITY] [REGULATORY] [NATIONAL] Policy supp...
# 3      [FOOD] [ECONOMIC] [NATIONAL] Investment in agr...
# 4      [FOOD] [ECONOMIC] [NATIONAL] Providing support...
# 5      [FOOD] [ECONOMIC] [NATIONAL] Targeting subsidi...
# 6      [NATURE] [PARTICIPATORY] [NGO] Use of particip...
# ...                                                  ...
# 20905  [SOCIAL] [ECONOMIC] [NATIONAL] China should co...
# 20906  [SOCIAL] [ECONOMIC] [NATIONAL] China should vi...
# 20908  [INDUSTRY] [ORGANISATIONAL] [COMPANIES] Manage...
# 20909  [INDUSTRY] [INFORMATIONAL] [COMPANIES] Service...
# 20910  [INDUSTRY] [INFORMATIONAL] [COMPANIES] Service...
#
# [14801 rows x 3 columns]

# %%
def extract_tags(policy):
    # policy is of form [DOMAIN] [POLCIY_TYPE] [ACTOR] text
    parts = policy.split("] ")
    if len(parts) < 4:
        raise ValueError(f"Policy does not have enough parts: {policy}")
    domain = parts[0][1:]  # remove leading '['
    policy_type = parts[1][1:]  # remove leading '['
    actor = parts[2][1:]  # remove leading '['
    policy_text = parts[-1]
    return {
        "domain": domain,
        "policy_type": policy_type,
        "actor": actor,
        "policy_text": policy_text,
    }

# %%
parts = pdf['policies'].apply(lambda x: len(x.split("] ")))

# %%
parts[parts != 4]
# Out:
# 2139     19
# 2649     25
# 3645      5
# 5036      7
# 7761      3
# 11239    22
# 13187     6
# 13188     5
# 15645    13
# 19715     5
# 20387    13
# 20536     5
# Name: policies, dtype: int64

# %%
for idx, row in pdf[parts != 4].iterrows():
    print(f"Row {idx}: {row['policies']}")
# Out:
# Row 2139: [SOCIAL] [ORGANISATIONAL] [NATIONAL] Policies to better support traditional healing practices in First Nation communities, including systemic federal support. [SOCIAL] [ORGANISATIONAL] [NATIONAL] Implementation of the Truth and Reconciliation Commission of Canada’s Calls to Action 18 and 19, which involves expanding the scope and mandate of health facilities in southern communities to include essential PHC services in all First Nation communities. [SOCIAL] [ORGANISATIONAL] [NATIONAL] Equitable rights-based funding and equitable access to PHC in each First Nation community. [SOCIAL] [ORGANISATIONAL] [NATIONAL] Active involvement of Indigenous Peoples in Canada in developing long-term structural changes to address systematic social and health inequities. [SOCIAL] [ORGANISATIONAL] [NATIONAL] Improving the living conditions for all First Nations living on reserve, reducing systemic and jurisdictional barriers, and addressing racism within the healthcare system. [SOCIAL] [ORGANISATIONAL] [NATIONAL] Coordinated effort by all levels of government to close the gap between First Nations and all other Manitobans (and Canadians).
# Row 2649: [NATURE] [SPATIAL] [NATIONAL] Policy-makers should fully consider the reducing abilities of ecological land, such as forests and grassland, on the concentration of particulate matters. [BUILDING] [SPATIAL] [NATIONAL] Controlling the expansion of built-up land and reasonably increasing the area of green space within cities are strongly suggested. [MOBILITY] [ORGANISATIONAL] [NATIONAL] Vigorously develop urban public transport, reduce the use of private vehicles and improve the quality of gasoline. [INDUSTRY] [ECONOMIC] [NATIONAL] Regional economic growth should avoid excessive dependence on the secondary industry, and consider the feasibility of regional industrial transformation. [ENERGY] [RESEARCH] [NATIONAL] Development and application of new energy sources to replace traditional fuels. [INDUSTRY] [REGULATORY] [NATIONAL] Improve laws and regulations on punishment of illegal discharge, increase the cost of violation on enterprises. [SOCIAL] [INFORMATIONAL] [NATIONAL] Strengthen public education to enhance environmental protection awareness. [MOBILITY] [PARTICIPATORY] [INDIVIDUALS] Residents should enhance environmental awareness and make contributions to control air pollution in China.
# Row 3645: [INDUSTRY] [REGULATORY] [NATIONAL] The Government [through the aforementioned bodies/agencies/institutions] should exercise continuous technical oversight (monitoring & support) over Sandcrete block-making factories in the country, so as to ensure the production of high-quality Sandcrete blocks across the country.
# Row 5036: [SOCIAL] [INFORMATIONAL] [NATIONAL] The National Institute for Health and Care Excellence guidelines recommend using the six to eight week postnatal check to discuss women’s weight, but only for women with a pre-pregnancy BMI of 30 kg/m2 or more. [SOCIAL] [INFORMATIONAL] [INTERNATIONAL] The World Health Organization (WHO) recommends waiting at least 24 months after a previous live birth.
# Row 7761: [MOBILITY] [REGULATORY] Congestion pricing strategy in Jordan
# Row 11239: [FOOD] [ECONOMIC] [NATIONAL] The Supplemental Nutrition Assistance Program (SNAP) provides food assistance to low-income individuals and families, including older adults. [FOOD] [ECONOMIC] [NATIONAL] Meals on Wheels delivers meals to homebound older adults. [FOOD] [ECONOMIC] [NATIONAL] The Commodity Supplemental Food Program provides food assistance to low-income older adults. [FOOD] [ECONOMIC] [NATIONAL] The Senior Farmers’ Market Nutrition Program provides coupons to low-income older adults for purchasing fresh fruits and vegetables. [FOOD] [ECONOMIC] [NATIONAL] The Emergency Food Assistance Program provides emergency food assistance to low-income individuals and families, including older adults. [FOOD] [REGULATORY] [NATIONAL] Some states have eligibility restrictions for food assistance programs that may exclude individuals with felony drug convictions. [SOCIAL] [REGULATORY] [NATIONAL] System policies that impose collateral consequences on formerly incarcerated individuals, such as difficulty finding stable employment and stable housing, should be re-examined and implemented to include this population.
# Row 13187: [SOCIAL] [PARTICIPATORY] [NGO] Nature prescription programs that encourage patients to spend time outdoors for their health, typically through tracked prescriptions for activities, locations, or guided outings. [NATIONAL] National programs like Park Rx America, with prescribers operating in 37 states. [REGIONAL] Regionally based programs like Washington state’s Parkscriptions program, with detailed databases of prescribable parks and activities accessed through phone or web apps to enable clinicians to make tailored recommendations.
# Row 13188: [SOCIAL] [PARTICIPATORY] [COMPANIES] Partnering with a hospital or clinic to host a week-long or two-week summer camp for children with mental health concerns, particularly anxiety or depression, following the Fear Facers Summer Camp model designed by the University of Florida. [SCHOOL] Operated by University of Florida clinicians (PhD-level psychologists), with undergraduate counselors and local parks and recreation facilities, targeting children ages 8–15 with anxiety and obsessive-compulsive disorders and pairing group activities, both indoor and outdoor, with one-on-one outdoor therapy sessions.
# Row 15645: [SOCIAL] [INFORMATIONAL] [NATIONAL] Reshape the value orientation of higher vocational colleges to focus on humanistic values, all-round development of students, and overall employment quality. [SOCIAL] [INFORMATIONAL] [NATIONAL] Avoid using 'enrollment rate' as the only quality standard for general basic education and 'employment rate' as the only quality evaluation index for vocational education. [INDUSTRY] [SPATIAL] [NATIONAL] Precise positioning of industrial demand and professional settings in higher vocational colleges to achieve hierarchical and structural integration of 'production' and 'teaching', and to optimize the professional structure and highlight the characteristics of colleges and universities. [SOCIAL] [INFORMATIONAL] [NATIONAL] Innovate teaching methods and reform the curriculum system in higher vocational colleges to improve the teaching quality and guarantee the employment quality of graduates.
# Row 19715: [SOCIAL] [ECONOMIC] [NATIONAL] Capitation supplements based on higher historical budget allocations (mean practice income guarantee [MPIG] payments) to general practices.
# Row 20387: [NATURE] [REGULATORY] [NATIONAL] Water authorities should implement strong eutrophication control measures to prevent cyanobacterial blooms, as only very low cyanobacteria biomass will guarantee non-hazardous conditions. This is particularly important in tropical areas where waters are more vulnerable to eutrophication. [NATURE] [REGULATORY] [NATIONAL] Regulatory agencies must control nutrient content/input into water systems to manage eutrophication and its indirect effects on cyanobacteria blooms, especially in the context of global warming and extreme climatic events. [NATURE] [REGULATORY] [NATIONAL] Governing bodies should work to preserve pristine ecosystems to maintain their resilience against nutrient enrichment and other environmental changes. [NATURE] [RESEARCH] [SCHOOL] Further research is needed to better understand the potential resilience observed in oligo-mesotrophic systems from tropical regions.
# Row 20536: [SOCIAL] [INFORMATIONAL] [COMPANIES] [NGO] Guiding enterprises and social organizations in improving farmers’ digital skills to assist farmers in obtaining timely and accurate information on work, entrepreneurship, and agricultural production through Internet usage.

# %% [markdown]
# Most of these could be repaired, but they're few enough to just throw them away.

# %%
tags_df = pdf["policies"][parts == 4].apply(extract_tags).apply(pd.Series)
pdf = pd.concat([pdf[parts == 4], tags_df], axis=1)
pdf
# Out:
#        openalex_id                                         discussion  \
# 2      W3048162401  LPG, CNG, ethanol and biodiesel are good candi...
# 3      W1005805659  The results of the study revealed that growth ...
# 4      W1005805659  The results of the study revealed that growth ...
# 5      W1005805659  The results of the study revealed that growth ...
# 6      W4319601041  In our use of participatory video, following R...
# ...            ...                                                ...
# 20905  W4387449772  Research findings\nAccording to the context of...
# 20906  W4387449772  Research findings\nAccording to the context of...
# 20908  W3005356321  In this paper, we explored the causal relation...
# 20909  W3005356321  In this paper, we explored the causal relation...
# 20910  W3005356321  In this paper, we explored the causal relation...
#
#                                                 policies    domain  \
# 2      [MOBILITY] [REGULATORY] [NATIONAL] Policy supp...  MOBILITY
# 3      [FOOD] [ECONOMIC] [NATIONAL] Investment in agr...      FOOD
# 4      [FOOD] [ECONOMIC] [NATIONAL] Providing support...      FOOD
# 5      [FOOD] [ECONOMIC] [NATIONAL] Targeting subsidi...      FOOD
# 6      [NATURE] [PARTICIPATORY] [NGO] Use of particip...    NATURE
# ...                                                  ...       ...
# 20905  [SOCIAL] [ECONOMIC] [NATIONAL] China should co...    SOCIAL
# 20906  [SOCIAL] [ECONOMIC] [NATIONAL] China should vi...    SOCIAL
# 20908  [INDUSTRY] [ORGANISATIONAL] [COMPANIES] Manage...  INDUSTRY
# 20909  [INDUSTRY] [INFORMATIONAL] [COMPANIES] Service...  INDUSTRY
# 20910  [INDUSTRY] [INFORMATIONAL] [COMPANIES] Service...  INDUSTRY
#
#           policy_type      actor  \
# 2          REGULATORY   NATIONAL
# 3            ECONOMIC   NATIONAL
# 4            ECONOMIC   NATIONAL
# 5            ECONOMIC   NATIONAL
# 6       PARTICIPATORY        NGO
# ...               ...        ...
# 20905        ECONOMIC   NATIONAL
# 20906        ECONOMIC   NATIONAL
# 20908  ORGANISATIONAL  COMPANIES
# 20909   INFORMATIONAL  COMPANIES
# 20910   INFORMATIONAL  COMPANIES
#
#                                              policy_text
# 2      Policy support for the implementation of biodi...
# 3      Investment in agriculture technology developme...
# 4      Providing support like credit, cheap power, tu...
# 5      Targeting subsidies to the poor and backward r...
# 6      Use of participatory video to bring Indigenous...
# ...                                                  ...
# 20905  China should consistently narrow income gaps t...
# 20906  China should vigorously promote the sharing ec...
# 20908  Managers should take cultural intelligence int...
# 20909  Service firms need to provide multicultural tr...
# 20910  Service firms should encourage employees to co...
#
# [14789 rows x 7 columns]

# %% [markdown]
# ### Clean invalid tags

# %%
accepted_domains = {"BUILDING", "URBAN", "MOBILITY", "ENERGY", "MATERIALS", "FOOD", "INDUSTRY", "LOGISTICS", "NATURE", "SOCIAL", "MACROECONOMIC"}
domain_mapping = {
    "AGRICULTURE": "FOOD",
    "ECONOMIC": "MACROECONOMIC",
    "FINANCE": "MACROECONOMIC",
    "INDIVIDUALS": "SOCIAL",
    "SCHOOL": "SOCIAL",
    "WATER": "MATERIALS",
    "TOURISM": None
}
domain_mapping |= {domain: domain for domain in accepted_domains}

# %%
pdf.domain = pdf.domain.map(domain_mapping)

# %%
pdf.groupby('domain').size()
# Out:
# domain
# BUILDING          455
# ENERGY           1568
# FOOD             2531
# INDUSTRY         1137
# LOGISTICS         102
# MACROECONOMIC     278
# MATERIALS         579
# MOBILITY          730
# NATURE           1687
# SOCIAL           4426
# URBAN            1285
# dtype: int64

# %%
pdf.drop(columns=['policies', 'discussion']).reset_index(drop=True).to_parquet('../data/cleaned_policies_from_sample10k_tagged_v4_2026-01-30.parquet')

# %% [markdown]
# ### LLM-based clustering

# %%
import os
from pydantic import BaseModel
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
client = OpenAI(
    base_url=os.getenv("GENERATION_API_URL"),
    api_key=os.getenv("SCW_SECRET_KEY"),
)

# %%
class PolicySubdomain(BaseModel):
    name: str
    clusters: list[str]

class PolicyHierarchy(BaseModel):
    subdomains: list[PolicySubdomain]

# %%
def extract_clusters(text: str, prompt: str, model_name: str, client: OpenAI = client) -> str:
    try:
        response = client.chat.completions.create(
            model=model_name,
            messages=[
                {"role": "system", "content": prompt.strip()},
                {"role": "user", "content": text},
            ],
            temperature=0,
            max_tokens=1024 * 16,
            response_format={
                "type": "json_schema",
                "json_schema": {
                    "name": PolicyHierarchy.__name__,
                    "schema": PolicyHierarchy.model_json_schema(),
                },
            },
            timeout=300,
            stream=False,
        )
        return PolicyHierarchy.model_validate_json(response.choices[0].message.content)
    except Exception as e:
        print("Error:", e)
        return f"Error: {e}"

# %%
#model_name = "mistral-small-3.2-24b-instruct-2506"
model_name = "qwen3-235b-a22b-instruct-2507"  # much better than the above model at identifying good clusters
cluster_prompt = """Group the following policies into clusters of roughly similar policies.
All policies belong to the same domain, your task is to output of list of subdomains, each with a list of clusters of similar policies.
Do not include the policies themselves in the output, only the names of the subdomains and clusters.

Roughly similar means policies sharing a similar mechanism.
For instance, carbon pricing policies would all be in the same cluster.
Still, the granularity of the clusters should be rather fine. 

The following example clusters are too broad:
- pollution control -> we're interested in the how, not the what, so we want to separate pollution control policies by their mechanism (tax, regulation, etc.)
- circular economy and waste management -> these are two different objectives, we want to separate them. Even separated, they would still be too broad, as they include very different policies (e.g. extended producer responsibility and landfill tax are both circular economy policies but very different in nature).
- sustainable farming practices -> again, way too broad, which practices ? or which policies to promote these practices ?
- Building materials and construction techniques -> which ones?

Our goal is to get a set of unique policies.

Here are the policies:
"""

merge_clusters_prompt = """
The following taxonomies are exracted from the same process applied to different samples of policies.
There will likely be some overlap / duplicates at all hierarchy levels.
Merge them into a single taxonomy.
"""

# %%
max_policies = 1000
outputs = {}
for domain, group in tqdm(pdf.groupby('domain')):
    group = pdf[pdf.domain == domain]
    policies = group['policy_text'].tolist()
    print(f"{domain} - {len(policies)} policies |", end=' ')
    
    for i in range(0, len(policies), max_policies):
        chunk = policies[i:i+max_policies]
        print(len(chunk), end=' ')
        query = "\n\n".join(chunk)
        #output = llm_call(query, cluster_prompt, model_name, temperature=0, max_tokens=16*1024, timeout=60)
        output = extract_clusters(query, cluster_prompt, model_name)
        outputs.setdefault(domain, []).append(output)
    print()
# Out:
# SOCIAL - 4426 policies | 1000 1000 Error: Request timed out.
# 1000 1000 426
# URBAN - 1285 policies | 1000 285

# %%
final = {}
for domain, taxonomies in outputs.items():
    if len(taxonomies) == 1:
        final[domain] = taxonomies[0]
    else:
        str_taxonomies = "\n\n".join([taxonomy.model_dump_json() for taxonomy in taxonomies])
        final[domain] = extract_clusters(str_taxonomies, merge_clusters_prompt, model_name)

# %%
# this was used to fix errors in the cell above

#str_taxonomies = "\n\n".join([taxonomy.model_dump_json() for taxonomy in outputs['SOCIAL']])
#final['SOCIAL'] = extract_clusters(str_taxonomies, merge_clusters_prompt, model_name)

#str_taxonomies = "\n\n".join([taxonomy.model_dump_json() for taxonomy in outputs['URBAN']])
#final['URBAN'] = extract_clusters(str_taxonomies, merge_clusters_prompt, model_name)

# %%
tmp = []
for domain, hierarchy in final.items():
    for subdomain in hierarchy.subdomains:
        print(f"{domain} - {subdomain.name} - {len(subdomain.clusters)} clusters")
        tmp.append((domain, subdomain.name, subdomain.clusters))
# Out:
# BUILDING - Building Energy Efficiency and Decarbonization - 5 clusters
# BUILDING - Housing Affordability, Access, and Social Equity - 5 clusters
# BUILDING - Passive and Climate-Responsive Design - 5 clusters
# BUILDING - Structural Safety, Resilience, and Geotechnical Engineering - 5 clusters
# BUILDING - Sustainable Construction Materials and Methods - 5 clusters
# BUILDING - Indoor Environmental Quality and Health - 5 clusters
# BUILDING - Urban Green Infrastructure and Water Management - 5 clusters
# BUILDING - Digitalization and Smart Building Technologies - 5 clusters
# BUILDING - Geotechnical and Foundation Engineering - 5 clusters
# BUILDING - Fire Safety in Buildings - 4 clusters
# BUILDING - Financing and Incentive Mechanisms for Building Upgrades - 5 clusters
# BUILDING - Housing Flexibility, Adaptability, and Inclusivity - 5 clusters
# BUILDING - Well-being and Human-Centered Design - 4 clusters
# BUILDING - Construction Sector Policy and Governance - 4 clusters
# BUILDING - Sustainable Tourism and Hospitality - 3 clusters
# BUILDING - Renewable Energy Integration and Electrification - 4 clusters
# BUILDING - Agricultural and Industrial Building Environmental Control - 3 clusters
# ENERGY - Carbon Pricing and Emissions Management - 6 clusters
# ENERGY - Renewable Energy Financial Incentives - 8 clusters
# ENERGY - Energy Pricing and Tariff Mechanisms - 7 clusters
# ENERGY - Energy Efficiency and Building Standards - 12 clusters
# ENERGY - Public Awareness and Behavioral Change - 7 clusters
# ENERGY - Grid Infrastructure and Modernization - 7 clusters
# ENERGY - Distributed and Decentralized Energy Systems - 4 clusters
# ENERGY - Renewable Energy Technology Deployment - 18 clusters
# ENERGY - Energy Storage Development and Integration - 3 clusters
# ENERGY - Fossil Fuel Transition and Phase-Out - 7 clusters
# ENERGY - Climate Targets and National Commitments - 6 clusters
# ENERGY - Pollution and Emissions Regulation - 7 clusters
# ENERGY - Green Finance and Investment - 7 clusters
# ENERGY - Energy Governance and Regulation - 7 clusters
# ENERGY - Energy Research, Development and Innovation - 7 clusters
# ENERGY - Energy Access and Equity - 7 clusters
# ENERGY - Industrial Energy and Decarbonization - 7 clusters
# ENERGY - Sectoral Energy Transitions - 7 clusters
# ENERGY - Monitoring, Reporting and Verification (MRV) - 7 clusters
# ENERGY - Energy and Environmental Planning - 7 clusters
# ENERGY - Digital Economy and Energy Use - 6 clusters
# ENERGY - Circular Economy and Resource Efficiency - 4 clusters
# ENERGY - Hydrogen Economy Development - 4 clusters
# ENERGY - Bioenergy and Biofuels - 4 clusters
# ENERGY - Wind Energy Development - 4 clusters
# ENERGY - Solar Energy Deployment - 4 clusters
# ENERGY - Other Renewable Energy Technologies - 4 clusters
# ENERGY - Energy Security and Resilience - 4 clusters
# ENERGY - Water-Energy Nexus - 4 clusters
# ENERGY - Energy Market Design - 4 clusters
# ENERGY - Financial Incentives and Support Mechanisms - 3 clusters
# ENERGY - International Climate Cooperation - 2 clusters
# ENERGY - Technology Innovation and R&D - 2 clusters
# ENERGY - Electrification and Sector Coupling - 2 clusters
# ENERGY - Digitalization and Smart Systems - 2 clusters
# FOOD - Agricultural Infrastructure and Market Access - 5 clusters
# FOOD - Agricultural Input and Production Subsidies - 9 clusters
# FOOD - Agricultural Credit and Financial Support - 4 clusters
# FOOD - Agricultural Extension and Capacity Building - 7 clusters
# FOOD - Agricultural Risk Management and Insurance - 7 clusters
# FOOD - Organic Agriculture Policy - 6 clusters
# FOOD - Precision and Digital Agriculture - 7 clusters
# FOOD - Soil and Water Conservation Practices - 9 clusters
# FOOD - Pest and Disease Management - 9 clusters
# FOOD - Nutrient Management and Fertilization - 7 clusters
# FOOD - Agroforestry and Tree-Based Systems - 7 clusters
# FOOD - Climate-Smart Agriculture - 7 clusters
# FOOD - Crop Breeding and Genetic Improvement - 3 clusters
# FOOD - Water Resource Management - 8 clusters
# FOOD - Food Safety and Quality Assurance - 7 clusters
# FOOD - Nutrition and Dietary Guidance - 7 clusters
# FOOD - Food Security and Social Protection - 8 clusters
# FOOD - Agricultural Trade and Market Regulation - 7 clusters
# FOOD - Agricultural Climate Mitigation - 6 clusters
# FOOD - Livestock Health and Management - 7 clusters
# FOOD - Fisheries and Aquaculture Policy - 10 clusters
# FOOD - Agricultural Waste and Circular Economy - 8 clusters
# FOOD - Land Use and Tenure Policy - 11 clusters
# FOOD - Farmer Organizations and Value Chain Development - 7 clusters
# FOOD - Gender and Labor Equity in Agriculture - 9 clusters
# FOOD - Sustainable Consumption and Eco-Labeling - 3 clusters
# FOOD - Bioenergy and Renewable Energy Policy - 7 clusters
# FOOD - Urban and Local Food Systems - 7 clusters
# FOOD - Agricultural Research and Innovation - 6 clusters
# FOOD - Disaster Risk Management - 5 clusters
# FOOD - Seed and Biotechnology Regulation - 3 clusters
# FOOD - Crisis and Conflict-Related Trade Policy - 3 clusters
# FOOD - Agrivoltaics and Energy Integration - 3 clusters
# FOOD - Traditional and Nutritious Crop Promotion - 3 clusters
# FOOD - Agricultural Contaminant Control - 3 clusters
# FOOD - Digital Supply Chain and Traceability - 4 clusters
# FOOD - Agritourism and Rural Tourism - 3 clusters
# FOOD - Agricultural Data and Monitoring Systems - 3 clusters
# FOOD - Mental Health and Nutrition - 3 clusters
# FOOD - Agricultural Labor and Workforce Development - 3 clusters
# FOOD - Natural Disaster and Erosion Control - 3 clusters
# FOOD - Carbon Accounting and Monitoring - 3 clusters
# FOOD - Agricultural Policy Evaluation and Modeling - 3 clusters
# FOOD - Consumer Behavior and Food Environment - 3 clusters
# FOOD - Social Inclusion and Equity - 3 clusters
# FOOD - Carbon Pricing - 2 clusters
# INDUSTRY - Environmental and Industrial Oversight - 4 clusters
# INDUSTRY - Workplace Safety and Risk Management - 5 clusters
# INDUSTRY - Leadership and Organizational Culture - 4 clusters
# INDUSTRY - Employee Self-Efficacy and Psychological Development - 4 clusters
# INDUSTRY - Green Human Resource Practices - 4 clusters
# INDUSTRY - Green Technology Incentives and Standards - 4 clusters
# INDUSTRY - Circular Economy and Waste Management - 4 clusters
# INDUSTRY - Digitalization and Technology Adoption - 4 clusters
# INDUSTRY - Carbon and Emissions Regulation - 4 clusters
# INDUSTRY - Sustainable Construction and Materials - 4 clusters
# INDUSTRY - Industrial Process Optimization and Emissions Control - 4 clusters
# INDUSTRY - Mining and Extractive Industry Safety and Sustainability - 4 clusters
# INDUSTRY - Employee Retention and Work-Life Balance - 4 clusters
# INDUSTRY - Diversity, Equity, and Inclusion - 4 clusters
# INDUSTRY - Collaborative Governance and Standards - 4 clusters
# INDUSTRY - Sustainable Supply Chain Management - 4 clusters
# INDUSTRY - Innovation and Technology Development - 4 clusters
# INDUSTRY - Industrial Policy and Economic Restructuring - 4 clusters
# INDUSTRY - Hydraulic Fracturing Regulation - 4 clusters
# INDUSTRY - Corporate Social Responsibility and Ethics - 4 clusters
# INDUSTRY - Employee Motivation and Engagement - 4 clusters
# INDUSTRY - Workplace Wellness and Physical Health - 4 clusters
# INDUSTRY - Environmental Regulation Mechanisms - 4 clusters
# INDUSTRY - Trade and Industrial Competitiveness - 4 clusters
# INDUSTRY - Bio-Based Economy and Sustainable Materials - 4 clusters
# INDUSTRY - Psychosocial Safety and Mental Health - 4 clusters
# INDUSTRY - Green Infrastructure and Urban Planning - 4 clusters
# INDUSTRY - Sustainable Product Lifecycle Management - 4 clusters
# INDUSTRY - Digital Economy Policy and Infrastructure - 4 clusters
# INDUSTRY - Employee Ownership and Profit-Sharing - 4 clusters
# INDUSTRY - Environmental Taxation and Financial Instruments - 4 clusters
# INDUSTRY - Critical Materials and Resource Security - 3 clusters
# INDUSTRY - Construction Waste Management - 4 clusters
# INDUSTRY - Energy Transition and Decarbonization - 4 clusters
# INDUSTRY - Hazardous Waste Management - 4 clusters
# INDUSTRY - Environmental Law and Legal Reform - 4 clusters
# INDUSTRY - Offshore Oil Production Technology - 4 clusters
# INDUSTRY - Rural and Agricultural Development - 4 clusters
# INDUSTRY - Education and Workforce Development - 4 clusters
# INDUSTRY - Organizational Restructuring and Change Management - 4 clusters
# INDUSTRY - Standardization and Technical Regulation - 4 clusters
# INDUSTRY - Regional and Urban Development - 4 clusters
# INDUSTRY - Corporate Financial Management - 4 clusters
# INDUSTRY - Market Orientation and Customer Engagement - 4 clusters
# INDUSTRY - Competition and Antitrust Policy - 3 clusters
# INDUSTRY - Labor Rights and Social Protection - 3 clusters
# INDUSTRY - Tourism and Hospitality Workforce - 3 clusters
# INDUSTRY - Defense Industry Policy - 3 clusters
# INDUSTRY - Performance Monitoring and Evaluation - 3 clusters
# INDUSTRY - Gender-Inclusive Economic Development - 3 clusters
# INDUSTRY - Healthcare Waste and Public Health - 3 clusters
# INDUSTRY - Textile Industry Sustainability - 3 clusters
# INDUSTRY - Sustainable Agriculture and Food Systems - 3 clusters
# INDUSTRY - Corporate Governance and Accountability - 3 clusters
# INDUSTRY - Sustainable Human Resource Management - 3 clusters
# INDUSTRY - Energy Efficiency and Sustainable Manufacturing - 5 clusters
# INDUSTRY - Advanced Maintenance and Equipment Management - 4 clusters
# INDUSTRY - Eco-Industrial Parks and Industrial Symbiosis - 4 clusters
# INDUSTRY - Digital Industrial Development and Digital Transformation - 4 clusters
# INDUSTRY - Circular Economy Enablers for SMEs - 4 clusters
# INDUSTRY - Industrial Water and Waste Stream Management - 3 clusters
# INDUSTRY - Low-Carbon Construction Materials - 2 clusters
# INDUSTRY - Sustainable Packaging and Logistics - 2 clusters
# INDUSTRY - Hazardous Substance Regulation and Substitution - 2 clusters
# INDUSTRY - Cleaner Production and Industrial Restructuring - 2 clusters
# INDUSTRY - Carbon Management and Emission Reduction Modeling - 3 clusters
# INDUSTRY - Regulatory and Legal Frameworks for Sustainable Ship Recycling - 4 clusters
# INDUSTRY - Environmental Regulation and Compliance Enforcement - 2 clusters
# INDUSTRY - Sustainable Industrial Policy and Innovation Incentives - 2 clusters
# INDUSTRY - Sustainable Forestry and Wood Processing - 2 clusters
# INDUSTRY - Corporate Social Responsibility and Stakeholder Engagement - 3 clusters
# INDUSTRY - Operational Efficiency and Inventory Optimization - 2 clusters
# INDUSTRY - Sustainability Advisory and Managerial Decision Support - 2 clusters
# LOGISTICS - Logistics and Supply Chain Management - 80 clusters
# LOGISTICS - Maritime and Port Operations - 5 clusters
# LOGISTICS - Rail and Inland Freight Infrastructure - 4 clusters
# LOGISTICS - Urban and Public Transport Systems - 3 clusters
# LOGISTICS - E-Commerce and Regional Market Integration - 3 clusters
# LOGISTICS - Cold Chain Logistics - 3 clusters
# LOGISTICS - Sustainable and Low-Carbon Logistics - 6 clusters
# LOGISTICS - Digitalization and Data Management in Logistics - 5 clusters
# LOGISTICS - Governance, Regulation, and Human Capital - 3 clusters
# LOGISTICS - Stakeholder Collaboration and Institutional Frameworks - 4 clusters
# MACROECONOMIC - Export Diversification and Trade Competitiveness - 3 clusters
# MACROECONOMIC - Trade Liberalization and Market Access - 4 clusters
# MACROECONOMIC - Foreign Direct Investment (FDI) Policies - 4 clusters
# MACROECONOMIC - Expansionary Fiscal Policy - 3 clusters
# MACROECONOMIC - Monetary Policy and Inflation Control - 4 clusters
# MACROECONOMIC - Exchange Rate Management - 4 clusters
# MACROECONOMIC - Labor Market and Employment Policies - 4 clusters
# MACROECONOMIC - Poverty Reduction and Inclusive Development - 4 clusters
# MACROECONOMIC - Digital Financial Inclusion - 4 clusters
# MACROECONOMIC - Tax Policy and Revenue Mobilization - 5 clusters
# MACROECONOMIC - Fiscal Federalism and Intergovernmental Finance - 3 clusters
# MACROECONOMIC - Market Structure and State Enterprise Reform - 3 clusters
# MACROECONOMIC - Economic Diversification and Structural Transformation - 3 clusters
# MACROECONOMIC - Green and Sustainable Growth - 3 clusters
# MACROECONOMIC - Climate Finance and Sustainable Funding - 3 clusters
# MACROECONOMIC - Environmental Policy Instruments - 3 clusters
# MACROECONOMIC - Resource Revenue Management - 3 clusters
# MACROECONOMIC - Financial Sector Reform and Interest Rate Policy - 3 clusters
# MACROECONOMIC - Macroprudential and Capital Flow Management - 3 clusters
# MACROECONOMIC - Human Capital and Education Policy - 3 clusters
# MACROECONOMIC - Infrastructure and Regional Development - 3 clusters
# MACROECONOMIC - Private Sector and Corporate Governance - 3 clusters
# MACROECONOMIC - Social Welfare and Household Resilience - 3 clusters
# MACROECONOMIC - International Investment Law and Arbitration - 2 clusters
# MACROECONOMIC - Global Climate Governance - 3 clusters
# MACROECONOMIC - Alternative Economic Paradigms - 2 clusters
# MACROECONOMIC - Environmental Liability and Compensation - 2 clusters
# MACROECONOMIC - Currency Internationalization and Financial Reform - 2 clusters
# MACROECONOMIC - Trade Competitiveness and Adjustment - 2 clusters
# MACROECONOMIC - Macroeconomic Stability and Crisis Management - 2 clusters
# MACROECONOMIC - Religious and Ethical Finance - 2 clusters
# MATERIALS - Pharmaceutical Waste Management - 2 clusters
# MATERIALS - Water Quality and Treatment - 8 clusters
# MATERIALS - Hazardous and Landfill Waste Management - 6 clusters
# MATERIALS - Water Infrastructure and Storage - 5 clusters
# MATERIALS - Water Economics and Market Instruments - 3 clusters
# MATERIALS - Community and Informal Waste Management - 4 clusters
# MATERIALS - Plastic and Textile Waste Management - 4 clusters
# MATERIALS - Construction and Demolition Waste - 3 clusters
# MATERIALS - Organic and Agricultural Waste - 3 clusters
# MATERIALS - Industrial and Agricultural Wastewater - 3 clusters
# MATERIALS - Municipal Solid Waste Management - 3 clusters
# MATERIALS - Water Conservation and Demand Management - 3 clusters
# MATERIALS - Mining and Extractive Waste - 3 clusters
# MATERIALS - Healthcare and Chemical Waste - 2 clusters
# MATERIALS - Sand and Aggregate Resource Management - 2 clusters
# MATERIALS - Water Governance and Transboundary Cooperation - 3 clusters
# MATERIALS - Flood, Sediment and Stormwater Management - 2 clusters
# MATERIALS - Water-Energy Nexus - 2 clusters
# MATERIALS - Circular Economy and Economic Instruments - 2 clusters
# MATERIALS - Water Equity and Access - 3 clusters
# MATERIALS - Environmental Monitoring and Data Systems - 2 clusters
# MATERIALS - Environmental Policy and Regulation - 2 clusters
# MATERIALS - Public Awareness and Education - 2 clusters
# MATERIALS - Climate Resilience and Coastal Management - 2 clusters
# MOBILITY - Alternative and Cleaner Fuels - 4 clusters
# MOBILITY - Electric Vehicle Incentives and Subsidies - 4 clusters
# MOBILITY - EV Charging Infrastructure - 4 clusters
# MOBILITY - Carbon Pricing and Emissions Trading - 4 clusters
# MOBILITY - Congestion and Road Pricing - 4 clusters
# MOBILITY - Public Transport Affordability Measures - 4 clusters
# MOBILITY - Public Transit Infrastructure and Service Enhancement - 4 clusters
# MOBILITY - Active Mobility Infrastructure - 4 clusters
# MOBILITY - Low- and Zero-Emission Zones - 4 clusters
# MOBILITY - Vehicle Emission and Efficiency Standards - 4 clusters
# MOBILITY - Port and Maritime Emissions Control - 4 clusters
# MOBILITY - Rail Transport Development and Electrification - 4 clusters
# MOBILITY - Road Infrastructure Development and Maintenance - 4 clusters
# MOBILITY - Intelligent and Smart Transport Systems - 4 clusters
# MOBILITY - Telework and Remote Mobility Policies - 3 clusters
# MOBILITY - Ride-Sharing and Carpooling Initiatives - 3 clusters
# MOBILITY - Integrated Urban and Land-Use Planning - 3 clusters
# MOBILITY - Aviation Emissions and Noise Management - 3 clusters
# MOBILITY - Migration and Refugee Mobility Policies - 3 clusters
# MOBILITY - Tourism Promotion and Marketing - 3 clusters
# MOBILITY - Equity and Environmental Justice in Transport - 3 clusters
# MOBILITY - Fleet Electrification Programs - 3 clusters
# MOBILITY - Freight and Logistics Management - 3 clusters
# MOBILITY - Driver Behavior and Education Programs - 3 clusters
# MOBILITY - Innovation and Technology Support Policies - 3 clusters
# MOBILITY - Winter Road and Ice Management - 3 clusters
# MOBILITY - Aviation Wildlife Hazard Management - 3 clusters
# MOBILITY - Disaster Risk and Early Warning Systems - 3 clusters
# MOBILITY - Water Service Governance - 3 clusters
# MOBILITY - Transport Safety Standards and Infrastructure - 3 clusters
# MOBILITY - Trade and Economic Corridor Development - 3 clusters
# MOBILITY - Digital and Labor Policy in Mobility Context - 3 clusters
# MOBILITY - Public Awareness and Behavioral Change Campaigns - 3 clusters
# MOBILITY - Energy Efficiency and Lifecycle Assessment - 3 clusters
# MOBILITY - Climate Adaptation and Resilience Planning - 3 clusters
# MOBILITY - Vehicle Ownership and Access Restrictions - 3 clusters
# MOBILITY - Informal and Paratransit Regulation - 3 clusters
# NATURE - Community and Indigenous Engagement - 11 clusters
# NATURE - Stakeholder Collaboration and Multi-Actor Governance - 5 clusters
# NATURE - Economic Incentives and Compensation Mechanisms - 8 clusters
# NATURE - Carbon and Emission Markets - 6 clusters
# NATURE - Regulatory and Legal Enforcement - 9 clusters
# NATURE - Environmental Education and Awareness - 7 clusters
# NATURE - Remote Sensing and Geospatial Monitoring - 9 clusters
# NATURE - Sustainable Forest Management Frameworks - 7 clusters
# NATURE - Afforestation and Reforestation Programs - 6 clusters
# NATURE - Wetland Restoration and Engineering - 7 clusters
# NATURE - Grazing and Pastoral Management - 7 clusters
# NATURE - Soil and Erosion Control Measures - 7 clusters
# NATURE - Integrated Water and Watershed Management - 7 clusters
# NATURE - Hydraulic and Structural Water Infrastructure - 4 clusters
# NATURE - Physical and Engineering Protection Infrastructure - 5 clusters
# NATURE - Air Pollution Control Policies - 8 clusters
# NATURE - Pollution Standards and Monitoring - 5 clusters
# NATURE - Invasive Species Management - 8 clusters
# NATURE - Protected Area Designation and Expansion - 8 clusters
# NATURE - Habitat and Ecological Connectivity Restoration - 5 clusters
# NATURE - Species Reintroduction and Captive Breeding - 6 clusters
# NATURE - Agroforestry and Integrated Land Use - 6 clusters
# NATURE - Urban Green Infrastructure and Planning - 6 clusters
# NATURE - Climate Change Adaptation and Resilience - 6 clusters
# NATURE - Disaster Risk Reduction and Early Warning - 6 clusters
# NATURE - Scientific Research and Monitoring Initiatives - 4 clusters
# NATURE - Environmental Policy Evaluation and Metrics - 4 clusters
# NATURE - Institutional and Legal Reforms - 7 clusters
# NATURE - Environmental Taxation and Financial Disincentives - 4 clusters
# NATURE - Community-Based Natural Resource Management - 4 clusters
# NATURE - Wildlife Protection and Species Legislation - 5 clusters
# NATURE - International Environmental Agreements - 4 clusters
# NATURE - Environmental Assessment and Review Processes - 4 clusters
# NATURE - Citizen Science and Public Participation in Monitoring - 5 clusters
# NATURE - Wastewater and Sewage Management - 6 clusters
# NATURE - Solid Waste and Plastic Management - 8 clusters
# NATURE - Agricultural Pollution Control - 6 clusters
# NATURE - Renewable Energy and Clean Technology Incentives - 4 clusters
# NATURE - Marine and Coastal Zone Management - 4 clusters
# NATURE - Ecotourism and Sustainable Tourism Development - 2 clusters
# NATURE - Infrastructure Planning and Ecological Connectivity - 3 clusters
# NATURE - Specialized Ecosystem Protection - 5 clusters
# NATURE - Drought and Water Scarcity Management - 2 clusters
# SOCIAL - Clinical Decision-Making and Preventive Care - 3 clusters
# SOCIAL - Workplace Well-being and Organizational Culture - 7 clusters
# SOCIAL - Health Promotion and Lifestyle Interventions - 5 clusters
# SOCIAL - Labor Market and Economic Development - 5 clusters
# SOCIAL - Caregiver and Family Support - 5 clusters
# SOCIAL - Healthcare Financing and Delivery Models - 5 clusters
# SOCIAL - Adult Literacy and Non-Formal Education - 5 clusters
# SOCIAL - Sexuality Education and Reproductive Health - 3 clusters
# SOCIAL - Mental Health Screening and Intervention - 26 clusters
# SOCIAL - School-Based Behavioral and Emotional Support - 4 clusters
# SOCIAL - Aging, Elder Care and Long-Term Care Systems - 5 clusters
# SOCIAL - Disability Inclusion and Support Across Lifespan - 4 clusters
# SOCIAL - Migration, Refugee Integration and Community Resilience - 13 clusters
# SOCIAL - Indigenous Rights and Culturally Responsive Policies - 12 clusters
# SOCIAL - Gender Equity and Women's Empowerment - 23 clusters
# SOCIAL - Counter-Radicalization and Reintegration - 4 clusters
# SOCIAL - Digital Inclusion and Technology Integration - 12 clusters
# SOCIAL - Environmental Education and Community Sustainability - 12 clusters
# SOCIAL - Financial Inclusion and Economic Empowerment - 9 clusters
# SOCIAL - Chronic Disease Management and Health Communication - 11 clusters
# SOCIAL - Public Safety and Harm Reduction - 3 clusters
# SOCIAL - Inclusive Education and Teacher Preparation - 9 clusters
# SOCIAL - Community-Based Non-Communicable Disease Prevention - 4 clusters
# SOCIAL - Substance Use and Harm Reduction - 10 clusters
# SOCIAL - Reproductive Health and Family Planning - 8 clusters
# SOCIAL - Poverty Alleviation and Social Protection - 9 clusters
# SOCIAL - Education and Workforce Development - 9 clusters
# SOCIAL - Health Literacy and Public Education - 4 clusters
# SOCIAL - Climate Resilience in Health Systems - 6 clusters
# SOCIAL - Artificial Intelligence Policy and Governance - 9 clusters
# SOCIAL - Environmental and Waste Management Policy - 6 clusters
# SOCIAL - Occupational and Public Safety - 3 clusters
# SOCIAL - Social Work and Community Empowerment - 3 clusters
# SOCIAL - Pension and Retirement System Reform - 6 clusters
# SOCIAL - Workforce Welfare and Retention - 12 clusters
# SOCIAL - Emotional Intelligence in Organizational and Educational Settings - 3 clusters
# SOCIAL - Emergency Preparedness and Training Delivery - 2 clusters
# SOCIAL - Chronic Illness Rehabilitation and Support - 10 clusters
# SOCIAL - Digital Citizenship and Social Media in Education - 2 clusters
# SOCIAL - Flexible and Remote Work Policies - 5 clusters
# SOCIAL - Critical Data Literacy and Educational Equity - 2 clusters
# SOCIAL - Culturally Responsive Counseling and Youth Engagement - 2 clusters
# SOCIAL - Student Support and Burnout Prevention in Education - 4 clusters
# SOCIAL - Nature-Based Therapeutic and Social Interventions - 2 clusters
# SOCIAL - Language Rights and Multilingual Education - 2 clusters
# SOCIAL - Migration and Immigration Policy - 2 clusters
# SOCIAL - Occupational Stress and Burnout Management - 5 clusters
# SOCIAL - Disaster Risk Reduction and Emergency Response - 10 clusters
# SOCIAL - Curriculum Design and Pedagogical Innovation - 4 clusters
# SOCIAL - School Safety and Student Conduct - 2 clusters
# SOCIAL - Constitutional and Governance Rights - 4 clusters
# SOCIAL - Public Health Guidelines and Clinical Standards - 5 clusters
# SOCIAL - Resettlement and Livelihood Restoration - 2 clusters
# SOCIAL - Parental Leave and Work-Family Integration - 7 clusters
# SOCIAL - Rural and Remote Healthcare Access - 3 clusters
# SOCIAL - Geriatric Care and Frailty Prevention - 2 clusters
# SOCIAL - Digital Health and Telemedicine - 4 clusters
# SOCIAL - Education Technology and Digital Learning - 6 clusters
# SOCIAL - Community Health and Hygiene Education - 11 clusters
# SOCIAL - Air Quality and Emission Control - 6 clusters
# SOCIAL - Circular Economy and Regenerative Systems - 3 clusters
# SOCIAL - Mental Health and Psychosocial Support - 3 clusters
# SOCIAL - Health Workforce and Human Resources - 7 clusters
# SOCIAL - HIV and Chronic Disease Prevention and Support - 3 clusters
# SOCIAL - Mobile Health (mHealth) and Cost Sustainability - 2 clusters
# SOCIAL - Anti-Corruption and Legal Enforcement - 7 clusters
# SOCIAL - Surgical Care Optimization and Recovery - 2 clusters
# SOCIAL - Social Capital and Community Engagement - 9 clusters
# SOCIAL - Sustainable Consumption and Inclusive Growth - 2 clusters
# SOCIAL - Refugee and Humanitarian Health Programs - 2 clusters
# SOCIAL - Child Labor and Education Access - 2 clusters
# SOCIAL - School and Rural Health Promotion - 2 clusters
# SOCIAL - Governance and Policy Implementation - 6 clusters
# SOCIAL - Public Health and Healthcare Systems - 13 clusters
# SOCIAL - Digital Governance and Media Policy - 5 clusters
# SOCIAL - Organizational and Workplace Development - 7 clusters
# SOCIAL - Health Economics and Financing - 5 clusters
# SOCIAL - Oral Health - 5 clusters
# SOCIAL - Income and Financial Support - 8 clusters
# SOCIAL - Physical Activity and Lifestyle Promotion - 15 clusters
# SOCIAL - Labor and Employment Policy - 10 clusters
# SOCIAL - Disability Inclusion and Support - 6 clusters
# SOCIAL - Education Financing and Incentives - 7 clusters
# SOCIAL - Justice and Legal Reform - 5 clusters
# SOCIAL - Urban and Community Development - 9 clusters
# SOCIAL - Health Promotion and Prevention - 7 clusters
# SOCIAL - Research and Evaluation Methodology - 5 clusters
# SOCIAL - Workforce Development and Training - 5 clusters
# SOCIAL - Family and Caregiver Support - 7 clusters
# SOCIAL - Governance and Anti-Corruption - 5 clusters
# URBAN - Land Use Planning and Zoning - 9 clusters
# URBAN - Flood Risk and Disaster Management - 10 clusters
# URBAN - Coastal and Shoreline Adaptation - 8 clusters
# URBAN - Urban Greening and Climate Adaptation - 9 clusters
# URBAN - Urban Water and Stormwater Management - 9 clusters
# URBAN - Urban Heat Island and Microclimate Management - 4 clusters
# URBAN - Participatory and Inclusive Urban Governance - 7 clusters
# URBAN - Cultural and Heritage Integration in Urban Development - 7 clusters
# URBAN - Housing and Community Development - 4 clusters
# URBAN - Sustainable Mobility and Active Transportation - 7 clusters
# URBAN - Air Quality and Pollution Control - 8 clusters
# URBAN - Odour and Nuisance Regulation - 4 clusters
# URBAN - Geological Hazard and Slope Stability Management - 4 clusters
# URBAN - Agricultural and Rural Land Protection - 4 clusters
# URBAN - Tourism Development and Management - 6 clusters
# URBAN - Waste Management and Circular Economy - 4 clusters
# URBAN - Urban Agriculture and Food Systems - 3 clusters
# URBAN - Urban Regeneration and Brownfield Redevelopment - 3 clusters
# URBAN - Smart Cities and Digital Urban Governance - 9 clusters
# URBAN - Urban Energy and Carbon Management - 3 clusters
# URBAN - Disaster Risk Reduction and Emergency Management - 3 clusters
# URBAN - Land Tenure and Property Rights - 5 clusters
# URBAN - Urban Metabolism and Resource Management - 3 clusters
# URBAN - Public Space and Social Wellbeing - 8 clusters
# URBAN - Transport and Mobility Infrastructure - 3 clusters
# URBAN - Water and Energy Resource Management - 3 clusters
# URBAN - Equity, Justice and Inclusive Development - 6 clusters
# URBAN - Creative Economy and Cultural Industries - 3 clusters
# URBAN - Regional Development and Territorial Cohesion - 6 clusters
# URBAN - Urban Forestry and Ecological Restoration - 3 clusters
# URBAN - Urban Finance and Investment Mechanisms - 2 clusters
# URBAN - Built Environment Safety and Resilience - 3 clusters
# URBAN - Rural Development and Livelihood Support - 3 clusters

# %%
cdf = pd.DataFrame.from_records(tmp, columns=['domain', 'subdomain', 'cluster'])
cdf
# Out:
#        domain                                          subdomain  \
# 0    BUILDING     Building Energy Efficiency and Decarbonization
# 1    BUILDING   Housing Affordability, Access, and Social Equity
# 2    BUILDING              Passive and Climate-Responsive Design
# 3    BUILDING  Structural Safety, Resilience, and Geotechnica...
# 4    BUILDING     Sustainable Construction Materials and Methods
# ..        ...                                                ...
# 434     URBAN      Regional Development and Territorial Cohesion
# 435     URBAN          Urban Forestry and Ecological Restoration
# 436     URBAN            Urban Finance and Investment Mechanisms
# 437     URBAN            Built Environment Safety and Resilience
# 438     URBAN           Rural Development and Livelihood Support
#
#                                                cluster
# 0    [Building Energy Performance Certification and...
# 1    [Affordable and Social Housing Provision and A...
# 2    [Bioclimatic and Passive Design Principles, Da...
# 3    [Soil Stabilization and Geotechnical Engineeri...
# 4    [Green Building Certification Schemes and Ince...
# ..                                                 ...
# 434  [National and Regional Development Strategies,...
# 435  [Tree inventory and urban forest management (e...
# 436  [Public-private partnerships (PPPs) and open t...
# 437  [Construction standards and hazard zoning (e.g...
# 438  [Rural infrastructure development (e.g., roads...
#
# [439 rows x 3 columns]

# %%
cdf = cdf.explode('cluster', ignore_index=True)
cdf
# Out:
#         domain                                       subdomain  \
# 0     BUILDING  Building Energy Efficiency and Decarbonization
# 1     BUILDING  Building Energy Efficiency and Decarbonization
# 2     BUILDING  Building Energy Efficiency and Decarbonization
# 3     BUILDING  Building Energy Efficiency and Decarbonization
# 4     BUILDING  Building Energy Efficiency and Decarbonization
# ...        ...                                             ...
# 2180     URBAN         Built Environment Safety and Resilience
# 2181     URBAN         Built Environment Safety and Resilience
# 2182     URBAN        Rural Development and Livelihood Support
# 2183     URBAN        Rural Development and Livelihood Support
# 2184     URBAN        Rural Development and Livelihood Support
#
#                                                 cluster
# 0     Building Energy Performance Certification and ...
# 1     Energy Efficiency Standards and Codes for New ...
# 2     Thermal and Envelope Retrofit Programs for Exi...
# 3     Operational Energy Optimization and HVAC Contr...
# 4     Embodied Energy and Life Cycle Assessment (LCA...
# ...                                                 ...
# 2180  Building safety and resilience (e.g., earthqua...
# 2181  Material and design innovation (e.g., reflecti...
# 2182  Rural infrastructure development (e.g., roads,...
# 2183  Support for aging farmers and flexible employm...
# 2184    Rural-urban connectivity and mobility subsidies
#
# [2185 rows x 3 columns]

# %%
cdf.to_csv('../data/sample_10k_policy_clusters_llm_2026-02-12.csv')

# %%
cdf.to_parquet('../data/sample_10k_policy_clusters_llm_2026-02-12.parquet')
